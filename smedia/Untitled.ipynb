# %%
from django.db import models

# %%
from blog.models import Post

# %%
Post.objects.creat(name = 'apple')
Post.objects.all()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Post.objects.creat(name = 'apple')
#       2 Post.objects.all()
#
# AttributeError: 'Manager' object has no attribute 'creat'

# %%
Post.objects.create(name = 'apple')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Post.objects.create(name = 'apple')
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\manager.py:85, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      84 def manager_method(self, *args, **kwargs):
# ---> 85     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\query.py:669, in QuerySet.create(self, **kwargs)
#     664 def create(self, **kwargs):
#     665     """
#     666     Create a new object with the given kwargs, saving it to the database
#     667     and returning the created object.
#     668     """
# --> 669     obj = self.model(**kwargs)
#     670     self._for_write = True
#     671     obj.save(force_insert=True, using=self.db)
#
# ...

# %%
Post.objects.create(title = 'apple')
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Post.objects.create(title = 'apple')
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\manager.py:85, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      84 def manager_method(self, *args, **kwargs):
# ---> 85     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\query.py:671, in QuerySet.create(self, **kwargs)
#     669 obj = self.model(**kwargs)
#     670 self._for_write = True
# --> 671 obj.save(force_insert=True, using=self.db)
#     672 return obj
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\base.py:812, in Model.save(self, force_insert, force_update, using, update_fields)
#     809     if loaded_fields:
# ...

# %%
>>> fruit = Fruit.objects.create(name='Apple')
>>> fruit.name = 'Pear'
>>> fruit.save()
>>> Fruit.objects.values_list('name', flat=True)
<QuerySet ['Apple', 'Pear']>
# Out:
#   Cell In[6], line 5
#     <QuerySet ['Apple', 'Pear']>
#     ^
# SyntaxError: invalid syntax

# %%
'''
>>> fruit = Fruit.objects.create(name='Apple')
>>> fruit.name = 'Pear'
>>> fruit.save()
>>> Fruit.objects.values_list('name', flat=True)
<QuerySet ['Apple', 'Pear']>
'''

p = Post.objects.create(name='Apple')
p.name = 'Pear'
p.save()
q = Post.objects.all()
Post.objects.values_list('name', flat=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 9
#       1 '''
#       2 fruit = Fruit.objects.create(name='Apple')
#       3 fruit.name = 'Pear'
#    (...)
#       6 <QuerySet ['Apple', 'Pear']>
#       7 '''
# ----> 9 p = Post.objects.create(name='Apple')
#      10 p.name = 'Pear'
#      11 p.save()
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\manager.py:85, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      84 def manager_method(self, *args, **kwargs):
# ---> 85     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\query.py:669, in QuerySet.create(self, **kwargs)
#     664 def create(self, **kwargs):
#     665     """
#     666     Create a new object with the given kwargs, saving it to the database
# ...

# %%
p = Post.objects.create(title='Apple')
p.name = 'Pear'
p.save()
q = Post.objects.all()
q
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 p = Post.objects.create(title='Apple')
#       2 p.name = 'Pear'
#       3 p.save()
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\manager.py:85, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      84 def manager_method(self, *args, **kwargs):
# ---> 85     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\query.py:671, in QuerySet.create(self, **kwargs)
#     669 obj = self.model(**kwargs)
#     670 self._for_write = True
# --> 671 obj.save(force_insert=True, using=self.db)
#     672 return obj
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\base.py:812, in Model.save(self, force_insert, force_update, using, update_fields)
# ...

# %%
p = Post.objects.create(name='Apple')
p.name = 'Pear'
p.save()
q = Post.objects.all()
Post.objects.values_list('name', flat=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 p = Post.objects.create(name='Apple')
#       2 p.name = 'Pear'
#       3 p.save()
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\manager.py:85, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      84 def manager_method(self, *args, **kwargs):
# ---> 85     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\query.py:669, in QuerySet.create(self, **kwargs)
#     664 def create(self, **kwargs):
#     665     """
#     666     Create a new object with the given kwargs, saving it to the database
#     667     and returning the created object.
#     668     """
# --> 669     obj = self.model(**kwargs)
#     670     self._for_write = True
# ...

# %%
p = Post.objects.create(title='Apple')
p.name = 'Pear'
p.save()
q = Post.objects.all()
Post.objects.values_list('title', flat=True)
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 p = Post.objects.create(title='Apple')
#       2 p.name = 'Pear'
#       3 p.save()
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\manager.py:85, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      84 def manager_method(self, *args, **kwargs):
# ---> 85     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\query.py:671, in QuerySet.create(self, **kwargs)
#     669 obj = self.model(**kwargs)
#     670 self._for_write = True
# --> 671 obj.save(force_insert=True, using=self.db)
#     672 return obj
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\base.py:812, in Model.save(self, force_insert, force_update, using, update_fields)
# ...

# %%
p = Post.objects.create(title='Apple')
p.title = 'Pear'
p.save()
q = Post.objects.all()
Post.objects.values_list('title', flat=True)
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 p = Post.objects.create(title='Apple')
#       2 p.natitleme = 'Pear'
#       3 p.save()
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\manager.py:85, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      84 def manager_method(self, *args, **kwargs):
# ---> 85     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\query.py:671, in QuerySet.create(self, **kwargs)
#     669 obj = self.model(**kwargs)
#     670 self._for_write = True
# --> 671 obj.save(force_insert=True, using=self.db)
#     672 return obj
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\base.py:812, in Model.save(self, force_insert, force_update, using, update_fields)
# ...

# %%
p = Post.objects.create(title='Apple')
p.title = 'Pear'
p.save()
Post.objects.values_list('title', flat=True)
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 p = Post.objects.create(title='Apple')
#       2 p.title = 'Pear'
#       3 p.save()
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\manager.py:85, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      84 def manager_method(self, *args, **kwargs):
# ---> 85     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\query.py:671, in QuerySet.create(self, **kwargs)
#     669 obj = self.model(**kwargs)
#     670 self._for_write = True
# --> 671 obj.save(force_insert=True, using=self.db)
#     672 return obj
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\base.py:812, in Model.save(self, force_insert, force_update, using, update_fields)
# ...

# %%
p = Post.objects.create(title='Apple')
p.title = 'Pear'
p.save()
Post.objects.values_list('title', flat=True)
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 p = Post.objects.create(title='Apple')
#       2 p.title = 'Pear'
#       3 p.save()
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\manager.py:85, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      84 def manager_method(self, *args, **kwargs):
# ---> 85     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\query.py:671, in QuerySet.create(self, **kwargs)
#     669 obj = self.model(**kwargs)
#     670 self._for_write = True
# --> 671 obj.save(force_insert=True, using=self.db)
#     672 return obj
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\base.py:812, in Model.save(self, force_insert, force_update, using, update_fields)
# ...

# %%
w = Post.objects.all()

# %%
w
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# File D:\python\smedia\venv\lib\site-packages\IPython\core\formatters.py:706, in PlainTextFormatter.__call__(self, obj)
#     699 stream = StringIO()
#     700 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     701     self.max_width, self.newline,
#     702     max_seq_length=self.max_seq_length,
#     703     singleton_pprinters=self.singleton_printers,
#     704     type_pprinters=self.type_printers,
#     705     deferred_pprinters=self.deferred_printers)
# --> 706 printer.pretty(obj)
#     707 printer.flush()
#     708 return stream.getvalue()
#
# File D:\python\smedia\venv\lib\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
# ...

# %%
print(w)
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(w)
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\query.py:370, in QuerySet.__repr__(self)
#     369 def __repr__(self):
# --> 370     data = list(self[: REPR_OUTPUT_SIZE + 1])
#     371     if len(data) > REPR_OUTPUT_SIZE:
#     372         data[-1] = "...(remaining elements truncated)..."
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\query.py:376, in QuerySet.__len__(self)
#     375 def __len__(self):
# --> 376     self._fetch_all()
#     377     return len(self._result_cache)
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\query.py:1867, in QuerySet._fetch_all(self)
#    1865 def _fetch_all(self):
#    1866     if self._result_cache is None:
# -> 1867         self._result_cache = list(self._iterable_class(self))
# ...

# %%
w[0]
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 w[0]
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\query.py:445, in QuerySet.__getitem__(self, k)
#     443 qs = self._chain()
#     444 qs.query.set_limits(k, k + 1)
# --> 445 qs._fetch_all()
#     446 return qs._result_cache[0]
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\query.py:1867, in QuerySet._fetch_all(self)
#    1865 def _fetch_all(self):
#    1866     if self._result_cache is None:
# -> 1867         self._result_cache = list(self._iterable_class(self))
#    1868     if self._prefetch_related_lookups and not self._prefetch_done:
#    1869         self._prefetch_related_objects()
#
# File D:\python\smedia\venv\lib\site-packages\django\db\models\query.py:87, in ModelIterable.__iter__(self)
#      84 compiler = queryset.query.get_compiler(using=db)
# ...

# %%
w = Post.objects.all()
w
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# File D:\python\smedia\venv\lib\site-packages\IPython\core\formatters.py:706, in PlainTextFormatter.__call__(self, obj)
#     699 stream = StringIO()
#     700 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     701     self.max_width, self.newline,
#     702     max_seq_length=self.max_seq_length,
#     703     singleton_pprinters=self.singleton_printers,
#     704     type_pprinters=self.type_printers,
#     705     deferred_pprinters=self.deferred_printers)
# --> 706 printer.pretty(obj)
#     707 printer.flush()
#     708 return stream.getvalue()
#
# File D:\python\smedia\venv\lib\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
# ...
